# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
titanic = sns.load_dataset("titanic")
print(titanic.head())
print(titanic.describe(include="all"))
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# ...

# %%
print(titanic[['age', 'fare']].agg(['mean', 'median']))
print(titanic[['sex', 'class', 'embark_town']].mode())
# Out:
#               age       fare
# mean    29.699118  32.204208
# median  28.000000  14.454200
#     sex  class  embark_town
# 0  male  Third  Southampton

# %%
sns.set_style("whitegrid")
categorical_features = ['sex', 'pclass', 'embarked', 'who']
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
for ax, feature in zip(axes.flatten(), categorical_features):
    sns.countplot(x=feature, hue="survived", data=titanic, ax=ax)
    ax.set_title(f"Survival Count by {feature}")
plt.tight_layout()
plt.show()

# %%
import numpy as np
corr_matrix = titanic.corr(numeric_only=True)
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Titanic Dataset")
plt.show()
